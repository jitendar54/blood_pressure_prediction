# %%
import pandas as pd #data analysis and converting the data into dataframe
import numpy as np #numpy for array processing
import matplotlib.pyplot as plt #2D graph plotting
from sklearn.metrics import r2_score
data=pd.read_csv('data.csv') #reading the dataset
data.head() #displaying the dataset into tabular format
# Out:
#    Age  Weight         SBP
# 0   58      58  158.657118
# 1   65      90  159.342444
# 2   56      96  153.516056
# 3   61      72  155.236048
# 4   65      62  149.324298

# %%
data.tail()
# Out:
#     Age  Weight         SBP
# 89   63      90  158.104033
# 90   36      94  126.836732
# 91   60      90  151.953700
# 92   65      96  149.697360
# 93   65      96  158.461571

# %%
data.shape
# Out:
# (94, 3)

# %%
data.isnull().sum()
# Out:
# Age       0
# Weight    0
# SBP       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#              Age     Weight         SBP
# count  94.000000  94.000000   94.000000
# mean   58.925532  82.989362  148.794614
# std     7.682181  13.376673    8.947818
# min    36.000000  54.000000  124.881162
# 25%    53.000000  72.000000  142.256824
# 50%    60.000000  85.000000  150.104128
# 75%    64.750000  96.000000  154.355503
# max    85.000000  99.000000  167.854930

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     94 non-null     int64
#  1   Weight  94 non-null     int64
#  2   SBP     94 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 2.3 KB

# %%
data.cov()
# Out:
#               Age      Weight        SBP
# Age     59.015900    4.042210  52.624829
# Weight   4.042210  178.935369  -2.830123
# SBP     52.624829   -2.830123  80.063444

# %%
data.corr()
# Out:
#              Age    Weight       SBP
# Age     1.000000  0.039336  0.765577
# Weight  0.039336  1.000000 -0.023645
# SBP     0.765577 -0.023645  1.000000

# %%
x=data.iloc[:,0:2] #features/columns
x.head()
# Out:
#    Age  Weight
# 0   58      58
# 1   65      90
# 2   56      96
# 3   61      72
# 4   65      62

# %%
y=data.iloc[:,-1] #target or labels
y
# Out:
# 0     158.657118
# 1     159.342444
# 2     153.516056
# 3     155.236048
# 4     149.324298
#          ...
# 89    158.104033
# 90    126.836732
# 91    151.953700
# 92    149.697360
# 93    158.461571
# Name: SBP, Length: 94, dtype: float64

# %%
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[2.69387755, 0.53333333],
#        [3.55102041, 4.8       ],
#        [2.44897959, 5.6       ],
#        [3.06122449, 2.4       ],
#        [3.55102041, 1.06666667],
#        [1.46938776, 3.33333333],
#        [2.08163265, 2.        ],
#        [2.20408163, 5.6       ],
#        [3.79591837, 5.6       ],
#        [3.06122449, 0.        ],
#        [1.2244898 , 1.73333333],
#        [2.08163265, 6.        ],
#        [3.30612245, 2.66666667],
#        [3.30612245, 2.53333333],
#        [2.08163265, 4.13333333],
#        [4.28571429, 3.46666667],
#        [2.93877551, 5.6       ],
#        [2.69387755, 3.73333333],
#        [2.08163265, 5.6       ],
#        [3.91836735, 2.4       ],
#        [2.44897959, 4.8       ],
#        [2.44897959, 5.6       ],
#        [1.59183673, 2.4       ],
#        [0.73469388, 3.2       ],
#        [2.81632653, 5.6       ],
#        [1.59183673, 5.6       ],
#        [3.18367347, 0.        ],
#        [3.91836735, 1.73333333],
#        [2.32653061, 6.        ],
#        [2.32653061, 2.66666667],
#        [2.44897959, 2.53333333],
#        [3.06122449, 5.6       ],
#        [2.93877551, 2.26666667],
#        [2.69387755, 2.4       ],
#        [3.79591837, 4.13333333],
#        [3.18367347, 4.13333333],
#        [3.55102041, 5.6       ],
#        [3.06122449, 4.8       ],
#        [1.83673469, 5.6       ],
#        [2.32653061, 4.        ],
#        [3.42857143, 0.        ],
#        [3.79591837, 1.73333333],
#        [2.93877551, 5.6       ],
#        [2.93877551, 5.6       ],
#        [5.02040816, 0.        ],
#        [1.71428571, 1.73333333],
#        [3.55102041, 6.        ],
#        [1.95918367, 2.66666667],
#        [3.18367347, 2.53333333],
#        [3.18367347, 2.66666667],
#        [3.91836735, 5.6       ],
#        [3.55102041, 2.4       ],
#        [2.93877551, 4.8       ],
#        [6.        , 5.6       ],
#        [3.42857143, 5.6       ],
#        [1.95918367, 3.73333333],
#        [2.69387755, 5.6       ],
#        [2.08163265, 2.4       ],
#        [3.18367347, 0.8       ],
#        [3.79591837, 5.6       ],
#        [4.16326531, 5.6       ],
#        [2.20408163, 5.6       ],
#        [3.67346939, 3.6       ],
#        [2.08163265, 2.4       ],
#        [2.08163265, 3.2       ],
#        [1.95918367, 4.8       ],
#        [2.81632653, 5.6       ],
#        [3.55102041, 2.4       ],
#        [3.91836735, 5.6       ],
#        [3.18367347, 5.6       ],
#        [1.71428571, 3.2       ],
#        [2.57142857, 0.93333333],
#        [1.71428571, 4.66666667],
#        [4.40816327, 4.93333333],
#        [2.44897959, 1.33333333],
#        [0.85714286, 5.6       ],
#        [3.06122449, 5.6       ],
#        [1.83673469, 2.4       ],
#        [1.34693878, 1.06666667],
#        [2.57142857, 5.6       ],
#        [3.55102041, 4.8       ],
#        [3.18367347, 5.6       ],
#        [2.81632653, 1.2       ],
#        [3.79591837, 5.6       ],
#        [2.81632653, 5.6       ],
#        [2.32653061, 3.46666667],
#        [1.34693878, 3.73333333],
#        [1.95918367, 3.73333333],
#        [3.18367347, 5.6       ],
#        [3.30612245, 4.8       ],
#        [0.        , 5.33333333],
#        [2.93877551, 4.8       ],
#        [3.55102041, 5.6       ],
#        [3.55102041, 5.6       ]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor  #packages for decision tree
dtc_clf=DecisionTreeRegressor() #model creation
dtc_clf.fit(x_train,y_train) #model training
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtc_clf.predict(x_test)
y_pred
# Out:
# array([162.5753678, 146.3242998, 138.8888882, 133.3837178, 148.9336415,
#        162.5753678, 152.5929905, 151.0721922, 146.3242998, 165.9990044])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4507964490291414

# %%
pd.DataFrame({'actual':y_test,'prediction':y_pred})
# Out:
#         actual  prediction
# 40  158.487778  162.575368
# 22  137.819893  146.324300
# 55  135.412569  138.888888
# 72  141.424900  133.383718
# 0   158.657118  148.933641
# 26  154.967396  162.575368
# 39  138.233330  152.592991
# 67  147.536705  151.072192
# 10  134.018876  146.324300
# 44  167.854930  165.999004

# %%
from sklearn.ensemble import RandomForestRegressor
clf=RandomForestRegressor(n_estimators=50)
clf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=50)

# %%
y_pred2=clf.predict(x_test)
y_pred2
# Out:
# array([155.17813997, 140.95389392, 139.03164631, 135.46425414,
#        149.82748695, 155.37980302, 147.93932794, 152.38014028,
#        142.8128837 , 161.00050162])

# %%
pd.DataFrame({'actual':y_test,'prediction':y_pred2})
# Out:
#         actual  prediction
# 40  158.487778  155.178140
# 22  137.819893  140.953894
# 55  135.412569  139.031646
# 72  141.424900  135.464254
# 0   158.657118  149.827487
# 26  154.967396  155.379803
# 39  138.233330  147.939328
# 67  147.536705  152.380140
# 10  134.018876  142.812884
# 44  167.854930  161.000502

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.6907589149338971

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_linreg_all = LR.predict(x_test)
pred_linreg_all
# Out:
# array([153.48201404, 140.46707834, 142.93851578, 141.15869627,
#        148.30699263, 151.76990393, 145.4873354 , 154.1639592 ,
#        137.94727704, 164.61072974])

# %%
pd.DataFrame({'actual':y_test,'prediction':pred_linreg_all})
# Out:
#         actual  prediction
# 40  158.487778  153.482014
# 22  137.819893  140.467078
# 55  135.412569  142.938516
# 72  141.424900  141.158696
# 0   158.657118  148.306993
# 26  154.967396  151.769904
# 39  138.233330  145.487335
# 67  147.536705  154.163959
# 10  134.018876  137.947277
# 44  167.854930  164.610730

# %%
r2_score(y_test, pred_linreg_all)
# Out:
# 0.7391037521751049

# %%
import pickle
model_pkl_file = "bp.pkl"
with open(model_pkl_file, 'wb') as file:
    pickle.dump(LR, file)
